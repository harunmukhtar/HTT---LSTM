# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import OneHotEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os
with open("/content/drive/My Drive/Colab Notebooks/.../data/google tren-fix.csv", "r") as f:
  df = pd.read_csv(f, header=0, index_col='MONTH', dtype='int64', parse_dates=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, January to Desember
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2008    12 non-null     int64
#  1   2009    12 non-null     int64
#  2   2010    12 non-null     int64
#  3   2011    12 non-null     int64
#  4   2012    12 non-null     int64
#  5   2013    12 non-null     int64
#  6   2014    12 non-null     int64
#  7   2015    12 non-null     int64
#  8   2016    12 non-null     int64
#  9   2017    12 non-null     int64
#  10  2018    12 non-null     int64
#  11  2019    12 non-null     int64
#  12  2020    12 non-null     int64
#  13  2021    12 non-null     int64
# dtypes: int64(14)
# memory usage: 1.4+ KB

# %%
df
# Out:
#            2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# MONTH
# January     204   217   374   356   379   283   342   457   427   432   506
# Pebruary    177   208   333   317   308   321   426   358   393   415   489
# March       287   256   341   257   338   336   395   381   446   415   458
# April       198   333   313   304   302   314   397   390   398   454   439
# May         238   312   419   337   338   419   364   411   421   484   491
# Juny        212   291   278   297   339   385   357   391   376   424   419
# July        212   315   269   396   342   348   353   339   380   450   559
# August      213   283   318   259   310   354   448   418   406   510   539
# September   198   305   275   349   305   360   377   352   379   483   492
# October     207   350   287   256   340   341   322   367   408   441   460
# November    195   291   241   318   322   330   433   371   355   526   387
# Desember    209   220   351   313   278   362   388   388   450   396   410
#
#            2019  2020  2021
# MONTH
# January     452   518   235
# Pebruary    426   428   306
# March       457   377   280
# April       420   264   252
# May         448   247   209
# Juny        478   289   276
# July        459   221   206
# August      470   260   244
# September   477   285   279
# October     429   249   224
# November    442   247   224
# Desember    451   253   242

# %%
import pandas as pd
import os
with open("/content/drive/My Drive/Colab Notebooks/.../data/bps-fix.csv", "r") as f:
  series = pd.read_csv(f, index_col='MONTH', header=0)
series.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-b5429e41637b> in <module>
#       1 import pandas as pd
#       2 import os
# ----> 3 with open("/content/drive/My Drive/Colab Notebooks/M Abdul Azis/Revisi 3/data/bps-fix.csv", "r") as f:
#       4   series = pd.read_csv(f, index_col='MONTH', header=0)
#       5 series.info()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/M Abdul Azis/Revisi 3/data/bps-fix.csv'
